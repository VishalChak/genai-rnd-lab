# %%
import autogen
print("autogen ready")
# Out:
# autogen ready

# %%
from autogen import AssistantAgent, UserProxyAgent

# %%
planner = AssistantAgent(
    name = "planner",
    system_message = "Think, plan and decide actions",
    code_execution_config = {"use_docker" : False}
)

executor = UserProxyAgent(
    name = "executer",
    human_input_mode = "NEVER",
    max_consecutive_auto_reply = 5,
    is_termination_msg = lambda x :"Done" in x["content"],
    code_execution_config={"use_docker": False} 
)

executor.initiate_chat(
    planner,
    message = "write python code to add two numbers, execute it , and say Done" 
)
# Out:
# executer (to planner):
#
# write python code to add two numbers, execute it , and say Done
#
# --------------------------------------------------------------------------------
# planner (to executer):
#
#
#
# --------------------------------------------------------------------------------
# executer (to planner):
#
#
#
# --------------------------------------------------------------------------------
# planner (to executer):
#
#
#
# --------------------------------------------------------------------------------
# executer (to planner):
#
#
#
# --------------------------------------------------------------------------------
# planner (to executer):
#
#
#
# --------------------------------------------------------------------------------
# executer (to planner):
#
#
#
# --------------------------------------------------------------------------------
# planner (to executer):
#
#
#
# --------------------------------------------------------------------------------
# executer (to planner):
#
#
#
# --------------------------------------------------------------------------------
# planner (to executer):
#
#
#
# --------------------------------------------------------------------------------
# executer (to planner):
#
#
#
# --------------------------------------------------------------------------------
# planner (to executer):
#
#
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (e5f651b0-86bf-4f07-8e7b-ae5bff2d3540): Maximum number of consecutive auto-replies reached
# ChatResult(chat_id=202707634116028282981053034472163055064, chat_history=[{'content': 'write python code to add two numbers, execute it , and say Done', 'role': 'assistant', 'name': 'executer'}, {'content': '', 'role': 'user', 'name': 'planner'}, {'content': '', 'role': 'assistant', 'name': 'executer'}, {'content': '', 'role': 'user', 'name': 'planner'}, {'content': '', 'role': 'assistant', 'name': 'executer'}, {'content': '', 'role': 'user', 'name': 'planner'}, {'content': '', 'role': 'assistant', 'name': 'executer'}, {'content': '', 'role': 'user', 'name': 'planner'}, {'content': '', 'role': 'assistant', 'name': 'executer'}, {'content': '', 'role': 'user', 'name': 'planner'}, {'content': '', 'role': 'assistant', 'name': 'executer'}, {'content': '', 'role': 'user', 'name': 'planner'}], summary='', cost={'usage_including_cached_inference': {'total_cost': 0}, 'usage_excluding_cached_inference': {'total_cost': 0}}, human_input=[])
